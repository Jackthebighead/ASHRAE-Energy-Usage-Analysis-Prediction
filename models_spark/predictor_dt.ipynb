# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10.139.64.4:48189">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.0.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>spark://10.139.64.4:7077</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
train_df = spark.read.csv('/FileStore/tables/merge_pd.csv', header="true", inferSchema="true")
test_df = spark.read.csv('/FileStore/tables/merge_pd_test.csv', header="true", inferSchema="true")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(test_df.count())
print(train_df.count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">41697600
# 20216100
# </div>

# %%
test_df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+-----------+-----+-------+-----------+---------------+--------------+---------------+------------------+
# _c0|building_id|meter|site_id|square_feet|air_temperature|cloud_coverage|dew_temperature|sea_level_pressure|
# +---+-----------+-----+-------+-----------+---------------+--------------+---------------+------------------+
#   0|          0|    0|      0|       7432|           17.8|           4.0|           11.7|            1021.4|
#   1|          1|    0|      0|       2720|           17.8|           4.0|           11.7|            1021.4|
#   2|          2|    0|      0|       5376|           17.8|           4.0|           11.7|            1021.4|
#   3|          3|    0|      0|      23685|           17.8|           4.0|           11.7|            1021.4|
#   4|          4|    0|      0|     116607|           17.8|           4.0|           11.7|            1021.4|
#   5|          5|    0|      0|       8000|           17.8|           4.0|           11.7|            1021.4|
#   6|          6|    0|      0|      27926|           17.8|           4.0|           11.7|            1021.4|
#   7|          7|    0|      0|     121074|           17.8|           4.0|           11.7|            1021.4|
#   8|          7|    1|      0|     121074|           17.8|           4.0|           11.7|            1021.4|
#   9|          8|    0|      0|      60809|           17.8|           4.0|           11.7|            1021.4|
#  10|          9|    0|      0|      27000|           17.8|           4.0|           11.7|            1021.4|
#  11|          9|    1|      0|      27000|           17.8|           4.0|           11.7|            1021.4|
#  12|         10|    0|      0|     370773|           17.8|           4.0|           11.7|            1021.4|
#  13|         11|    0|      0|      49073|           17.8|           4.0|           11.7|            1021.4|
#  14|         12|    0|      0|      37100|           17.8|           4.0|           11.7|            1021.4|
#  15|         13|    0|      0|      99380|           17.8|           4.0|           11.7|            1021.4|
#  16|         13|    1|      0|      99380|           17.8|           4.0|           11.7|            1021.4|
#  17|         14|    0|      0|      86250|           17.8|           4.0|           11.7|            1021.4|
#  18|         14|    1|      0|      86250|           17.8|           4.0|           11.7|            1021.4|
#  19|         15|    0|      0|      83957|           17.8|           4.0|           11.7|            1021.4|
# +---+-----------+-----+-------+-----------+---------------+--------------+---------------+------------------+
# only showing top 20 rows
#
# </div>

# %%
train_df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+-----------+-----+-------------+-------+-----------+---------------+--------------+---------------+------------------+
# _c0|building_id|meter|meter_reading|site_id|square_feet|air_temperature|cloud_coverage|dew_temperature|sea_level_pressure|
# +---+-----------+-----+-------------+-------+-----------+---------------+--------------+---------------+------------------+
#   0|          0|    0|          0.0|      0|       7432|           25.0|           6.0|           20.0|            1019.7|
#   1|          1|    0|          0.0|      0|       2720|           25.0|           6.0|           20.0|            1019.7|
#   2|          2|    0|          0.0|      0|       5376|           25.0|           6.0|           20.0|            1019.7|
#   3|          3|    0|          0.0|      0|      23685|           25.0|           6.0|           20.0|            1019.7|
#   4|          4|    0|          0.0|      0|     116607|           25.0|           6.0|           20.0|            1019.7|
#   5|          5|    0|          0.0|      0|       8000|           25.0|           6.0|           20.0|            1019.7|
#   6|          6|    0|          0.0|      0|      27926|           25.0|           6.0|           20.0|            1019.7|
#   7|          7|    0|          0.0|      0|     121074|           25.0|           6.0|           20.0|            1019.7|
#   8|          8|    0|          0.0|      0|      60809|           25.0|           6.0|           20.0|            1019.7|
#   9|          9|    0|          0.0|      0|      27000|           25.0|           6.0|           20.0|            1019.7|
#  10|         10|    0|          0.0|      0|     370773|           25.0|           6.0|           20.0|            1019.7|
#  11|         11|    0|          0.0|      0|      49073|           25.0|           6.0|           20.0|            1019.7|
#  12|         12|    0|          0.0|      0|      37100|           25.0|           6.0|           20.0|            1019.7|
#  13|         13|    0|          0.0|      0|      99380|           25.0|           6.0|           20.0|            1019.7|
#  14|         14|    0|          0.0|      0|      86250|           25.0|           6.0|           20.0|            1019.7|
#  15|         15|    0|          0.0|      0|      83957|           25.0|           6.0|           20.0|            1019.7|
#  16|         16|    0|          0.0|      0|      54644|           25.0|           6.0|           20.0|            1019.7|
#  17|         17|    0|          0.0|      0|      15250|           25.0|           6.0|           20.0|            1019.7|
#  18|         18|    0|          0.0|      0|     111891|           25.0|           6.0|           20.0|            1019.7|
#  19|         19|    0|          0.0|      0|      18717|           25.0|           6.0|           20.0|            1019.7|
# +---+-----------+-----+-------------+-------+-----------+---------------+--------------+---------------+------------------+
# only showing top 20 rows
#
# </div>

# %%
train_df = train_df.drop('_c0')
test_df = test_df.drop('_c0')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
train_df = train_df.fillna(0.0, subset=['air_temperature', 'cloud_coverage', 'dew_temperature','sea_level_pressure'])
train_df = train_df.fillna(0, subset=['square_feet'])
train_df.cache()
test_df = test_df.fillna(0.0, subset=['air_temperature', 'cloud_coverage', 'dew_temperature','sea_level_pressure'])
test_df = test_df.fillna(0, subset=['square_feet'])
test_df.cache()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: DataFrame[building_id: int, meter: int, site_id: int, square_feet: int, air_temperature: double, cloud_coverage: double, dew_temperature: double, sea_level_pressure: double]</div>

# %%
from pyspark.ml.feature import VectorAssembler
 
feature_cols = list(train_df.columns)
print(feature_cols)
feature_cols.remove("meter_reading")
print(feature_cols)   
assembler = VectorAssembler(inputCols=feature_cols, outputCol="features")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;building_id&#39;, &#39;meter&#39;, &#39;meter_reading&#39;, &#39;site_id&#39;, &#39;square_feet&#39;, &#39;air_temperature&#39;, &#39;cloud_coverage&#39;, &#39;dew_temperature&#39;, &#39;sea_level_pressure&#39;]
# [&#39;building_id&#39;, &#39;meter&#39;, &#39;site_id&#39;, &#39;square_feet&#39;, &#39;air_temperature&#39;, &#39;cloud_coverage&#39;, &#39;dew_temperature&#39;, &#39;sea_level_pressure&#39;]
# </div>

# %%
#from pyspark.ml.regression import LogisticRegression
from pyspark.ml.regression import DecisionTreeRegressor
from pyspark.ml import Pipeline
 
rf = DecisionTreeRegressor(featuresCol='features', labelCol='meter_reading',maxDepth=16)

stages = [assembler, rf]
pipeline_model = Pipeline(stages=stages)
model = pipeline_model.fit(train_df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
predictions = model.transform(test_df)
predictions.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+-----+-------+-----------+---------------+--------------+---------------+------------------+--------------------+------------------+
# building_id|meter|site_id|square_feet|air_temperature|cloud_coverage|dew_temperature|sea_level_pressure|            features|        prediction|
# +-----------+-----+-------+-----------+---------------+--------------+---------------+------------------+--------------------+------------------+
#           0|    0|      0|       7432|           17.8|           4.0|           11.7|            1021.4|[0.0,0.0,0.0,7432...| 47.19954724857685|
#           1|    0|      0|       2720|           17.8|           4.0|           11.7|            1021.4|[1.0,0.0,0.0,2720...|12.981433852544129|
#           2|    0|      0|       5376|           17.8|           4.0|           11.7|            1021.4|[2.0,0.0,0.0,5376...| 47.19954724857685|
#           3|    0|      0|      23685|           17.8|           4.0|           11.7|            1021.4|[3.0,0.0,0.0,2368...| 58.44215703363913|
#           4|    0|      0|     116607|           17.8|           4.0|           11.7|            1021.4|[4.0,0.0,0.0,1166...|458.88304461883394|
#           5|    0|      0|       8000|           17.8|           4.0|           11.7|            1021.4|[5.0,0.0,0.0,8000...| 47.19954724857685|
#           6|    0|      0|      27926|           17.8|           4.0|           11.7|            1021.4|[6.0,0.0,0.0,2792...| 58.44215703363913|
#           7|    0|      0|     121074|           17.8|           4.0|           11.7|            1021.4|[7.0,0.0,0.0,1210...| 241.0096788359788|
#           7|    1|      0|     121074|           17.8|           4.0|           11.7|            1021.4|[7.0,1.0,0.0,1210...|1464.1070489977726|
#           8|    0|      0|      60809|           17.8|           4.0|           11.7|            1021.4|[8.0,0.0,0.0,6080...|137.50098907103825|
#           9|    0|      0|      27000|           17.8|           4.0|           11.7|            1021.4|[9.0,0.0,0.0,2700...| 58.44215703363913|
#           9|    1|      0|      27000|           17.8|           4.0|           11.7|            1021.4|[9.0,1.0,0.0,2700...|346.42525209205024|
#          10|    0|      0|     370773|           17.8|           4.0|           11.7|            1021.4|[10.0,0.0,0.0,370...|333.86955267857144|
#          11|    0|      0|      49073|           17.8|           4.0|           11.7|            1021.4|[11.0,0.0,0.0,490...|  71.7590440150295|
#          12|    0|      0|      37100|           17.8|           4.0|           11.7|            1021.4|[12.0,0.0,0.0,371...|  71.7590440150295|
#          13|    0|      0|      99380|           17.8|           4.0|           11.7|            1021.4|[13.0,0.0,0.0,993...|137.50098907103825|
#          13|    1|      0|      99380|           17.8|           4.0|           11.7|            1021.4|[13.0,1.0,0.0,993...| 691.9577773584907|
#          14|    0|      0|      86250|           17.8|           4.0|           11.7|            1021.4|[14.0,0.0,0.0,862...|137.50098907103825|
#          14|    1|      0|      86250|           17.8|           4.0|           11.7|            1021.4|[14.0,1.0,0.0,862...|1095.8299927184464|
#          15|    0|      0|      83957|           17.8|           4.0|           11.7|            1021.4|[15.0,0.0,0.0,839...|137.50098907103825|
# +-----------+-----+-------+-----------+---------------+--------------+---------------+------------------+--------------------+------------------+
# only showing top 20 rows
#
# </div>

# %%
print(predictions.count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">41697600
# </div>

# %%
predictions_df = predictions.select('prediction')
predictions_df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------------+
#         prediction|
# +------------------+
#  47.19954724857685|
# 12.981433852544129|
#  47.19954724857685|
#  58.44215703363913|
# 458.88304461883394|
#  47.19954724857685|
#  58.44215703363913|
#  241.0096788359788|
# 1464.1070489977726|
# 137.50098907103825|
#  58.44215703363913|
# 346.42525209205024|
# 333.86955267857144|
#   71.7590440150295|
#   71.7590440150295|
# 137.50098907103825|
#  691.9577773584907|
# 137.50098907103825|
# 1095.8299927184464|
# 137.50098907103825|
# +------------------+
# only showing top 20 rows
#
# </div>

# %%
prediction_pd = predictions_df.toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
prediction_pd.shape
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[46]: (41697600, 1)</div>

# %%
#prediction_pd.to_csv('/dbfs/FileStore/tables/result_1.csv')
predictions_df.cache()
predictions_df.coalesce(1).write.format('com.databricks.spark.csv').option('header', 'true').save('dbfs:/FileStore/tables/result_DT-depth16.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
